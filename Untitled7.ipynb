# %%
with open('yash.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Hey how are you

# %%
file = open('yash.txt' , 'r')
file = file.read()
print(file)
# Out:
# Hey how are you
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       2 file = file.read()
#       3 print(file)
# ----> 4 file.close()
#
# AttributeError: 'str' object has no attribute 'close'

# %%
with open('files.txt' , 'r') as f:
    file = f.read()
    print(f)
# Out:
# <_io.TextIOWrapper name='files.txt' mode='r' encoding='cp1252'>

# %%
with open('yash.csv' , 'r') as p:
    file = p.read()
    print(file)
# Out:
# Train No,Speed,City
# 22021,92,pune
# 10229,30,jalna
# 10110,89,bareli
# 29901,25,goa
